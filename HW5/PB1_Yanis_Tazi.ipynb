# %% [markdown]
# # Question 1:

# %%
! python eval_ssd.py --net mb1-ssd  --dataset data/VOC2007/ --trained_model models/mobilenet-v1-ssd-mp-0_675.pth --label_file models/voc-model-labels.txt
# Out:
# eval_ssd.py:69: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   all_gt_boxes[class_index][image_id] = torch.tensor(all_gt_boxes[class_index][image_id])
# It took 0.04209494590759277 seconds to load the model.
# process image 0
# Load Image: 0.004025 seconds.
# Inference time:  0.10561728477478027
# Prediction: 0.122345 seconds.
# process image 1
# Load Image: 0.003584 seconds.
# Inference time:  0.08668923377990723
# Prediction: 0.123001 seconds.
# process image 2
# Load Image: 0.003562 seconds.
# Inference time:  0.08736705780029297
# Prediction: 0.127344 seconds.
# process image 3
# Load Image: 0.004137 seconds.
# Inference time:  0.08863115310668945
# Prediction: 0.124801 seconds.
# process image 4
# Load Image: 0.003754 seconds.
# Inference time:  0.08515405654907227
# Prediction: 0.109492 seconds.
# process image 5
# ...

# %% [markdown]
# # Question 2:

# %%
! cd pytorch-ssd

# %%
! python open_images_downloader.py --root ~/data/open_images --class_names "Handgun,Shotgun" --num_workers 20
# Out:
# python: can't open file 'open_images_downloader.py': [Errno 2] No such file or directory

# %%
! pwd
# Out:
# /Users/taziy/DeepLearningSystems/HW5
